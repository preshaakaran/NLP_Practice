# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\tilak\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\tilak\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\tilak\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tilak\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\tilak\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\tilak\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tilak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tilak\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def text_similarity(text1, text2):
    # Tokenize the texts
    tokens1 = set(word_tokenize(text1.lower()))
    tokens2 = set(word_tokenize(text2.lower()))

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens1 = tokens1 - stop_words
    tokens2 = tokens2 - stop_words

    # Calculate Jaccard similarity coefficient
    intersection = len(tokens1.intersection(tokens2))
    union = len(tokens1.union(tokens2))
    similarity = intersection / union if union != 0 else 0

    return similarity

# %%
if __name__ == "__main__":
    # Example usage
    text1 = "Natural Language Processing is a fascinating field of study."
    text2 = "Studying Natural Language Processing is interesting."

    similarity_score = text_similarity(text1, text2)
    print(f"Similarity Score: {similarity_score}")
# Out:
# Similarity Score: 0.4444444444444444
